# %%
# %pip install selenium webdriver-manager beautifulsoup4
# Out:
# Requirement already satisfied: selenium in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (4.33.0)
# Requirement already satisfied: webdriver-manager in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (4.0.2)
# Requirement already satisfied: beautifulsoup4 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (4.13.4)
# Requirement already satisfied: urllib3~=2.4.0 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from urllib3[socks]~=2.4.0->selenium) (2.4.0)
# Requirement already satisfied: trio~=0.30.0 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.4.26 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from selenium) (2025.4.26)
# Requirement already satisfied: typing_extensions~=4.13.2 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from selenium) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8.0 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from trio~=0.30.0->selenium) (25.1.0)
# Requirement already satisfied: sortedcontainers in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from trio~=0.30.0->selenium) (3.10)
# Requirement already satisfied: outcome in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from trio~=0.30.0->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from urllib3[socks]~=2.4.0->selenium) (1.7.1)
# Requirement already satisfied: requests in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from webdriver-manager) (1.1.0)
# Requirement already satisfied: packaging in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from webdriver-manager) (24.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/clarexu/Downloads/.venv/lib/python3.13/site-packages (from requests->webdriver-manager) (3.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Set up ChromeDriver with Selenium
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Go to the TSX 60 page
url = "https://www.theglobeandmail.com/investing/markets/indices/TXSX/components/"
driver.get(url) # driver.get(url) tells Selenium to navigate to that page using Chrome.

# Wait for dynamic content to load
time.sleep(5)  # wait 5 seconds before scraping content. You can improve this with WebDriverWait

# Get the page source after JavaScript runs
html = driver.page_source # This HTML now includes all the dynamically loaded content (thanks to JavaScript).
soup = BeautifulSoup(html, 'html.parser') # Passes the HTML to BeautifulSoup to parse it and extract data in a more readable way (like .find() or .select()).

driver.quit()
# Closes the Chrome browser and ends the WebDriver session. Always good practice to clean up when you’re done scraping.

# %%
print(type(html))      # should be <class 'str'>
# Out:
# <class 'str'>

# %% [markdown]
# ```from selenium import webdriver```

# %% [markdown]
# This imports the **Selenium WebDriver module**, which allows you to control a web browser(e.g., Chrome) via Python.
#
#
# Selenium mimics a real user: it opens a browser window, clicks buttons, waits for pages to load, etc.

# %% [markdown]
# ```from selenium.webdriver.chrome.service import Service```

# %% [markdown]
# Imports the Service class from Selenium, which is used to configure and manage the ChromeDriver service instance.
#
#
# It handles the communication between your Python script and the Chrome browser.

# %% [markdown]
# ```from webdriver_manager.chrome import ChromeDriverManager```

# %% [markdown]
# This imports a utility to automatically download and install the correct version of ChromeDriver that matches your local Chrome browser.
#
#
# It prevents compatibility errors and saves you from manually managing chromedriver.exe.

# %% [markdown]
# ```from bs4 import BeautifulSoup```

# %% [markdown]
# Imports BeautifulSoup, a library used to parse HTML/XML content and extract data from web pages.
#
#
# After Selenium loads the page, we pass the HTML to BeautifulSoup to extract the info we need.

# %% [markdown]
# ```driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))```

# %% [markdown]
# Sets up and starts the Chrome browser.
#
#
# ChromeDriverManager().install() automatically gets the latest compatible ChromeDriver.
#
#
# Service(...) wraps this driver into a service.
#
#
# webdriver.Chrome(...) starts an actual Chrome browser that you can control.

# %%
a = soup.find_all('tr', attrs={'data-barchart-symbol': True})
a
# Uses BeautifulSoup to search the parsed HTML and extract specific rows (<tr> elements)
# Out:
# [<tr data-barchart-symbol="ABX-T">
#  <td class="fix-col text-left" data-barchart-field="symbol" data-barchart-field-type="symbol">
#  <barchart-link-field raw-symbol="ABX.TO" symbol="ABX-T" symbolname="Barrick Mining Corp" type="6" value="ABX-T">
#  <a href="/investing/markets/stocks/ABX-T/">ABX-T</a>
#  </barchart-link-field>
#  </td>
#  <td class="text-left" data-barchart-field="symbolName" data-barchart-field-type="symbolName">
#  <barchart-field binding="true" name="symbolName" symbol="ABX.TO" type="string" value="Barrick Mining Corp">Barrick Mining Corp</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="lastPrice" data-barchart-field-type="lastPrice">
#  <barchart-field binding="true" name="lastPrice" symbol="ABX.TO" type="price" value="27.15">27.15</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="priceChange" data-barchart-field-type="priceChange">
#  <barchart-field binding="true" class="quoteDown" name="priceChange" symbol="ABX.TO" type="priceChange" value="-0.20">-0.20<span class="sr-only">decrease</span></barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="percentChange" data-barchart-field-type="percentChange">
#  <barchart-field binding="true" class="quoteDown" name="percentChange" symbol="ABX.TO" type="percentChange" value="-0.73%">-0.73%<span class="sr-only">decrease</span></barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="openPrice" data-barchart-field-type="openPrice">
#  <barchart-field binding="true" name="openPrice" symbol="ABX.TO" type="price" value="27.37">27.37</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="highPrice" data-barchart-field-type="highPrice">
#  <barchart-field binding="true" name="highPrice" symbol="ABX.TO" type="price" value="27.43">27.43</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="lowPrice" data-barchart-field-type="lowPrice">
#  <barchart-field binding="true" name="lowPrice" symbol="ABX.TO" type="price" value="26.79">26.79</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="tradeTime" data-barchart-field-type="tradeTime">
#  <barchart-field binding="true" name="tradeTime" symbol="ABX.TO" type="time" value="06/06/25">06/06/25</barchart-field>
#  </td>
#  <td class="text-right hidden-print" data-barchart-field="quickLink" data-barchart-field-type="quickLink">
#  <barchart-quick-link quicklinks='{"links":{"1":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"},{"label":"Insiders","link":"{symbol}/insiders/"}],"2":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Related","link":"{symbol}/related/"},{"label":"Daily Price","link":"{symbol}/performance/"}],"5":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Research","link":"{symbol}/fundamentals/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"6":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"},{"label":"Insiders","link":"{symbol}/insiders/"}],"7":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"9":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Components","link":"{symbol}/components/"},{"label":"Daily Price","link":"{symbol}/performance/"}],"10":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"}],"11":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"15":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Research","link":"{symbol}/fundamentals/"},{"label":"Daily Prices","link":"{symbol}/performance/"}]},"tools":[{"label":"Add to Watchlist","attributeType":"barchart-watchlist"},{"label":"Add to Portfolio","attributeType":"barchart-portfolio"},{"label":"Create Alert","attributeType":"barchart-alert"}]}' quote='{"symbol":"ABX-T","symbolName":"Barrick Mining Corp","lastPrice":"27.15","priceChange":"-0.20","percentChange":"-0.73%","openPrice":"27.37","highPrice":"27.43","lowPrice":"26.79","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"ABX.TO","symbolName":"Barrick Mining Corp","lastPrice":27.15,"priceChange":-0.2,"percentChange":-0.0073,"openPrice":27.37,"highPrice":27.43,"lowPrice":26.79,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}' symbol="ABX-T" symboltype="6"><div class="quick-action-containers">
#  <!-- <span tabindex="0" role="button" class="quick-action glyphicon glyphicon-option-horizontal" data-toggle="popover" data-trigger="click"></span> -->
#  <span class="quick-action glyphicon glyphicon-option-horizontal"></span>
#  <!-- <a tabindex="0" role="button" class="quick-action glyphicon glyphicon-option-horizontal" data-toggle="popover" data-trigger="click"></a> -->
#  <div class="barchart-tool-link-container hidden">
#  <!-- <div class="barchart-point popover-content"> -->
#  <div class="barchart-point">
#  <div class="links-container">
#  <div class="action-titles action-titles-top">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Links
#                              </h5>
#  </div>
#  </div>
#  <div class="action-links">
#  <div class="link-holder row">
#  <div class="col-xs-6">
#  <a class="links" href="/investing/markets/stocks/ABX-T/">
#                                  Quote
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/full-chart/ABX-T/">
#                                  Chart
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ABX-T/profile/">
#                                  Profile
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ABX-T/statistics/">
#                                  Statistics
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ABX-T/financials/">
#                                  Earnings
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ABX-T/dividends/">
#                                  Dividends
#                                  </a>
#  </div><div class="col-xs-6">
#  <a class="links" href="/investing/markets/stocks/ABX-T/research/">
#                                  Research
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ABX-T/pressreleases/">
#                                  Press
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ABX-T/performance/">
#                                  Daily Prices
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ABX-T/insiders/">
#                                  Insiders
#                                  </a>
#  </div>
#  </div>
#  </div>
#  <div class="action-titles action-titles-bottom hidden">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Links
#                              </h5>
#  </div>
#  </div>
#  </div>
#  <div class="links-container">
#  <div class="action-titles action-titles-top">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Tools
#                              </h5>
#  </div>
#  </div>
#  <div class="action-links">
#  <div class="link-holder">
#  <a class="tools bc-add-to-watchlist" is="barchart-watchlist" quote='{"symbol":"ABX-T","symbolName":"Barrick Mining Corp","lastPrice":"27.15","priceChange":"-0.20","percentChange":"-0.73%","openPrice":"27.37","highPrice":"27.43","lowPrice":"26.79","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"ABX.TO","symbolName":"Barrick Mining Corp","lastPrice":27.15,"priceChange":-0.2,"percentChange":-0.0073,"openPrice":27.37,"highPrice":27.43,"lowPrice":26.79,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Add to Watchlist
#                                  </a>
#  <a class="tools" is="barchart-portfolio" quote='{"symbol":"ABX-T","symbolName":"Barrick Mining Corp","lastPrice":"27.15","priceChange":"-0.20","percentChange":"-0.73%","openPrice":"27.37","highPrice":"27.43","lowPrice":"26.79","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"ABX.TO","symbolName":"Barrick Mining Corp","lastPrice":27.15,"priceChange":-0.2,"percentChange":-0.0073,"openPrice":27.37,"highPrice":27.43,"lowPrice":26.79,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Add to Portfolio
#                                  </a>
#  <a class="tools" is="barchart-alert" quote='{"symbol":"ABX-T","symbolName":"Barrick Mining Corp","lastPrice":"27.15","priceChange":"-0.20","percentChange":"-0.73%","openPrice":"27.37","highPrice":"27.43","lowPrice":"26.79","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"ABX.TO","symbolName":"Barrick Mining Corp","lastPrice":27.15,"priceChange":-0.2,"percentChange":-0.0073,"openPrice":27.37,"highPrice":27.43,"lowPrice":26.79,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Create Alert
#                                  </a>
#  </div>
#  </div>
#  <div class="action-titles action-titles-bottom hidden">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Tools
#                              </h5>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div></barchart-quick-link>
#  </td>
#  </tr>,
#  <tr data-barchart-symbol="AEM-T">
#  <td class="fix-col text-left" data-barchart-field="symbol" data-barchart-field-type="symbol">
#  <barchart-link-field raw-symbol="AEM.TO" symbol="AEM-T" symbolname="Agnico Eagle Mines Ltd" type="6" value="AEM-T">
#  <a href="/investing/markets/stocks/AEM-T/">AEM-T</a>
#  </barchart-link-field>
#  </td>
#  <td class="text-left" data-barchart-field="symbolName" data-barchart-field-type="symbolName">
#  <barchart-field binding="true" name="symbolName" symbol="AEM.TO" type="string" value="Agnico Eagle Mines Ltd">Agnico Eagle Mines Ltd</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="lastPrice" data-barchart-field-type="lastPrice">
#  <barchart-field binding="true" name="lastPrice" symbol="AEM.TO" type="price" value="161.60">161.60</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="priceChange" data-barchart-field-type="priceChange">
#  <barchart-field binding="true" class="quoteDown" name="priceChange" symbol="AEM.TO" type="priceChange" value="-5.21">-5.21<span class="sr-only">decrease</span></barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="percentChange" data-barchart-field-type="percentChange">
#  <barchart-field binding="true" class="quoteDown" name="percentChange" symbol="AEM.TO" type="percentChange" value="-3.12%">-3.12%<span class="sr-only">decrease</span></barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="openPrice" data-barchart-field-type="openPrice">
#  <barchart-field binding="true" name="openPrice" symbol="AEM.TO" type="price" value="166.33">166.33</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="highPrice" data-barchart-field-type="highPrice">
#  <barchart-field binding="true" name="highPrice" symbol="AEM.TO" type="price" value="166.68">166.68</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="lowPrice" data-barchart-field-type="lowPrice">
#  <barchart-field binding="true" name="lowPrice" symbol="AEM.TO" type="price" value="160.46">160.46</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="tradeTime" data-barchart-field-type="tradeTime">
#  <barchart-field binding="true" name="tradeTime" symbol="AEM.TO" type="time" value="06/06/25">06/06/25</barchart-field>
#  </td>
#  <td class="text-right hidden-print" data-barchart-field="quickLink" data-barchart-field-type="quickLink">
#  <barchart-quick-link quicklinks='{"links":{"1":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"},{"label":"Insiders","link":"{symbol}/insiders/"}],"2":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Related","link":"{symbol}/related/"},{"label":"Daily Price","link":"{symbol}/performance/"}],"5":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Research","link":"{symbol}/fundamentals/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"6":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"},{"label":"Insiders","link":"{symbol}/insiders/"}],"7":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"9":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Components","link":"{symbol}/components/"},{"label":"Daily Price","link":"{symbol}/performance/"}],"10":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"}],"11":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"15":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Research","link":"{symbol}/fundamentals/"},{"label":"Daily Prices","link":"{symbol}/performance/"}]},"tools":[{"label":"Add to Watchlist","attributeType":"barchart-watchlist"},{"label":"Add to Portfolio","attributeType":"barchart-portfolio"},{"label":"Create Alert","attributeType":"barchart-alert"}]}' quote='{"symbol":"AEM-T","symbolName":"Agnico Eagle Mines Ltd","lastPrice":"161.60","priceChange":"-5.21","percentChange":"-3.12%","openPrice":"166.33","highPrice":"166.68","lowPrice":"160.46","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"AEM.TO","symbolName":"Agnico Eagle Mines Ltd","lastPrice":161.6,"priceChange":-5.21,"percentChange":-0.0312,"openPrice":166.33,"highPrice":166.68,"lowPrice":160.46,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}' symbol="AEM-T" symboltype="6"><div class="quick-action-containers">
#  <!-- <span tabindex="0" role="button" class="quick-action glyphicon glyphicon-option-horizontal" data-toggle="popover" data-trigger="click"></span> -->
#  <span class="quick-action glyphicon glyphicon-option-horizontal"></span>
#  <!-- <a tabindex="0" role="button" class="quick-action glyphicon glyphicon-option-horizontal" data-toggle="popover" data-trigger="click"></a> -->
#  <div class="barchart-tool-link-container hidden">
#  <!-- <div class="barchart-point popover-content"> -->
#  <div class="barchart-point">
#  <div class="links-container">
#  <div class="action-titles action-titles-top">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Links
#                              </h5>
#  </div>
#  </div>
#  <div class="action-links">
#  <div class="link-holder row">
#  <div class="col-xs-6">
#  <a class="links" href="/investing/markets/stocks/AEM-T/">
#                                  Quote
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/full-chart/AEM-T/">
#                                  Chart
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AEM-T/profile/">
#                                  Profile
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AEM-T/statistics/">
#                                  Statistics
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AEM-T/financials/">
#                                  Earnings
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AEM-T/dividends/">
#                                  Dividends
#                                  </a>
#  </div><div class="col-xs-6">
#  <a class="links" href="/investing/markets/stocks/AEM-T/research/">
#                                  Research
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AEM-T/pressreleases/">
#                                  Press
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AEM-T/performance/">
#                                  Daily Prices
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AEM-T/insiders/">
#                                  Insiders
#                                  </a>
#  </div>
#  </div>
#  </div>
#  <div class="action-titles action-titles-bottom hidden">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Links
#                              </h5>
#  </div>
#  </div>
#  </div>
#  <div class="links-container">
#  <div class="action-titles action-titles-top">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Tools
#                              </h5>
#  </div>
#  </div>
#  <div class="action-links">
#  <div class="link-holder">
#  <a class="tools bc-add-to-watchlist" is="barchart-watchlist" quote='{"symbol":"AEM-T","symbolName":"Agnico Eagle Mines Ltd","lastPrice":"161.60","priceChange":"-5.21","percentChange":"-3.12%","openPrice":"166.33","highPrice":"166.68","lowPrice":"160.46","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"AEM.TO","symbolName":"Agnico Eagle Mines Ltd","lastPrice":161.6,"priceChange":-5.21,"percentChange":-0.0312,"openPrice":166.33,"highPrice":166.68,"lowPrice":160.46,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Add to Watchlist
#                                  </a>
#  <a class="tools" is="barchart-portfolio" quote='{"symbol":"AEM-T","symbolName":"Agnico Eagle Mines Ltd","lastPrice":"161.60","priceChange":"-5.21","percentChange":"-3.12%","openPrice":"166.33","highPrice":"166.68","lowPrice":"160.46","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"AEM.TO","symbolName":"Agnico Eagle Mines Ltd","lastPrice":161.6,"priceChange":-5.21,"percentChange":-0.0312,"openPrice":166.33,"highPrice":166.68,"lowPrice":160.46,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Add to Portfolio
#                                  </a>
#  <a class="tools" is="barchart-alert" quote='{"symbol":"AEM-T","symbolName":"Agnico Eagle Mines Ltd","lastPrice":"161.60","priceChange":"-5.21","percentChange":"-3.12%","openPrice":"166.33","highPrice":"166.68","lowPrice":"160.46","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"AEM.TO","symbolName":"Agnico Eagle Mines Ltd","lastPrice":161.6,"priceChange":-5.21,"percentChange":-0.0312,"openPrice":166.33,"highPrice":166.68,"lowPrice":160.46,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Create Alert
#                                  </a>
#  </div>
#  </div>
#  <div class="action-titles action-titles-bottom hidden">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Tools
#                              </h5>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div></barchart-quick-link>
#  </td>
#  </tr>,
#  <tr data-barchart-symbol="AQN-T">
#  <td class="fix-col text-left" data-barchart-field="symbol" data-barchart-field-type="symbol">
#  <barchart-link-field raw-symbol="AQN.TO" symbol="AQN-T" symbolname="Algonquin Power and Utilities Corp" type="6" value="AQN-T">
#  <a href="/investing/markets/stocks/AQN-T/">AQN-T</a>
#  </barchart-link-field>
#  </td>
#  <td class="text-left" data-barchart-field="symbolName" data-barchart-field-type="symbolName">
#  <barchart-field binding="true" name="symbolName" symbol="AQN.TO" type="string" value="Algonquin Power and Utilities Corp">Algonquin Power and Utilities Corp</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="lastPrice" data-barchart-field-type="lastPrice">
#  <barchart-field binding="true" name="lastPrice" symbol="AQN.TO" type="price" value="8.02">8.02</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="priceChange" data-barchart-field-type="priceChange">
#  <barchart-field binding="true" class="quoteUp" name="priceChange" symbol="AQN.TO" type="priceChange" value="+0.03">+0.03<span class="sr-only">increase</span></barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="percentChange" data-barchart-field-type="percentChange">
#  <barchart-field binding="true" class="quoteUp" name="percentChange" symbol="AQN.TO" type="percentChange" value="+0.38%">+0.38%<span class="sr-only">increase</span></barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="openPrice" data-barchart-field-type="openPrice">
#  <barchart-field binding="true" name="openPrice" symbol="AQN.TO" type="price" value="8.00">8.00</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="highPrice" data-barchart-field-type="highPrice">
#  <barchart-field binding="true" name="highPrice" symbol="AQN.TO" type="price" value="8.04">8.04</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="lowPrice" data-barchart-field-type="lowPrice">
#  <barchart-field binding="true" name="lowPrice" symbol="AQN.TO" type="price" value="7.91">7.91</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="tradeTime" data-barchart-field-type="tradeTime">
#  <barchart-field binding="true" name="tradeTime" symbol="AQN.TO" type="time" value="06/06/25">06/06/25</barchart-field>
#  </td>
#  <td class="text-right hidden-print" data-barchart-field="quickLink" data-barchart-field-type="quickLink">
#  <barchart-quick-link quicklinks='{"links":{"1":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"},{"label":"Insiders","link":"{symbol}/insiders/"}],"2":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Related","link":"{symbol}/related/"},{"label":"Daily Price","link":"{symbol}/performance/"}],"5":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Research","link":"{symbol}/fundamentals/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"6":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"},{"label":"Insiders","link":"{symbol}/insiders/"}],"7":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"9":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Components","link":"{symbol}/components/"},{"label":"Daily Price","link":"{symbol}/performance/"}],"10":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"}],"11":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"15":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Research","link":"{symbol}/fundamentals/"},{"label":"Daily Prices","link":"{symbol}/performance/"}]},"tools":[{"label":"Add to Watchlist","attributeType":"barchart-watchlist"},{"label":"Add to Portfolio","attributeType":"barchart-portfolio"},{"label":"Create Alert","attributeType":"barchart-alert"}]}' quote='{"symbol":"AQN-T","symbolName":"Algonquin Power and Utilities Corp","lastPrice":"8.02","priceChange":"+0.03","percentChange":"+0.38%","openPrice":"8.00","highPrice":"8.04","lowPrice":"7.91","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"AQN.TO","symbolName":"Algonquin Power and Utilities Corp","lastPrice":8.02,"priceChange":0.03,"percentChange":0.0038,"openPrice":8,"highPrice":8.04,"lowPrice":7.91,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}' symbol="AQN-T" symboltype="6"><div class="quick-action-containers">
#  <!-- <span tabindex="0" role="button" class="quick-action glyphicon glyphicon-option-horizontal" data-toggle="popover" data-trigger="click"></span> -->
#  <span class="quick-action glyphicon glyphicon-option-horizontal"></span>
#  <!-- <a tabindex="0" role="button" class="quick-action glyphicon glyphicon-option-horizontal" data-toggle="popover" data-trigger="click"></a> -->
#  <div class="barchart-tool-link-container hidden">
#  <!-- <div class="barchart-point popover-content"> -->
#  <div class="barchart-point">
#  <div class="links-container">
#  <div class="action-titles action-titles-top">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Links
#                              </h5>
#  </div>
#  </div>
#  <div class="action-links">
#  <div class="link-holder row">
#  <div class="col-xs-6">
#  <a class="links" href="/investing/markets/stocks/AQN-T/">
#                                  Quote
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/full-chart/AQN-T/">
#                                  Chart
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AQN-T/profile/">
#                                  Profile
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AQN-T/statistics/">
#                                  Statistics
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AQN-T/financials/">
#                                  Earnings
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AQN-T/dividends/">
#                                  Dividends
#                                  </a>
#  </div><div class="col-xs-6">
#  <a class="links" href="/investing/markets/stocks/AQN-T/research/">
#                                  Research
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AQN-T/pressreleases/">
#                                  Press
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AQN-T/performance/">
#                                  Daily Prices
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/AQN-T/insiders/">
#                                  Insiders
#                                  </a>
#  </div>
#  </div>
#  </div>
#  <div class="action-titles action-titles-bottom hidden">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Links
#                              </h5>
#  </div>
#  </div>
#  </div>
#  <div class="links-container">
#  <div class="action-titles action-titles-top">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Tools
#                              </h5>
#  </div>
#  </div>
#  <div class="action-links">
#  <div class="link-holder">
#  <a class="tools bc-add-to-watchlist" is="barchart-watchlist" quote='{"symbol":"AQN-T","symbolName":"Algonquin Power and Utilities Corp","lastPrice":"8.02","priceChange":"+0.03","percentChange":"+0.38%","openPrice":"8.00","highPrice":"8.04","lowPrice":"7.91","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"AQN.TO","symbolName":"Algonquin Power and Utilities Corp","lastPrice":8.02,"priceChange":0.03,"percentChange":0.0038,"openPrice":8,"highPrice":8.04,"lowPrice":7.91,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Add to Watchlist
#                                  </a>
#  <a class="tools" is="barchart-portfolio" quote='{"symbol":"AQN-T","symbolName":"Algonquin Power and Utilities Corp","lastPrice":"8.02","priceChange":"+0.03","percentChange":"+0.38%","openPrice":"8.00","highPrice":"8.04","lowPrice":"7.91","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"AQN.TO","symbolName":"Algonquin Power and Utilities Corp","lastPrice":8.02,"priceChange":0.03,"percentChange":0.0038,"openPrice":8,"highPrice":8.04,"lowPrice":7.91,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Add to Portfolio
#                                  </a>
#  <a class="tools" is="barchart-alert" quote='{"symbol":"AQN-T","symbolName":"Algonquin Power and Utilities Corp","lastPrice":"8.02","priceChange":"+0.03","percentChange":"+0.38%","openPrice":"8.00","highPrice":"8.04","lowPrice":"7.91","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"AQN.TO","symbolName":"Algonquin Power and Utilities Corp","lastPrice":8.02,"priceChange":0.03,"percentChange":0.0038,"openPrice":8,"highPrice":8.04,"lowPrice":7.91,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Create Alert
#                                  </a>
#  </div>
#  </div>
#  <div class="action-titles action-titles-bottom hidden">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Tools
#                              </h5>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div></barchart-quick-link>
#  </td>
#  </tr>,
#  <tr data-barchart-symbol="ATD-T">
#  <td class="fix-col text-left" data-barchart-field="symbol" data-barchart-field-type="symbol">
#  <barchart-link-field raw-symbol="ATD.TO" symbol="ATD-T" symbolname="Alimentation Couche-Tard Inc." type="6" value="ATD-T">
#  <a href="/investing/markets/stocks/ATD-T/">ATD-T</a>
#  </barchart-link-field>
#  </td>
#  <td class="text-left" data-barchart-field="symbolName" data-barchart-field-type="symbolName">
#  <barchart-field binding="true" name="symbolName" symbol="ATD.TO" type="string" value="Alimentation Couche-Tard Inc.">Alimentation Couche-Tard Inc.</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="lastPrice" data-barchart-field-type="lastPrice">
#  <barchart-field binding="true" name="lastPrice" symbol="ATD.TO" type="price" value="72.14">72.14</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="priceChange" data-barchart-field-type="priceChange">
#  <barchart-field binding="true" class="quoteDown" name="priceChange" symbol="ATD.TO" type="priceChange" value="-0.25">-0.25<span class="sr-only">decrease</span></barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="percentChange" data-barchart-field-type="percentChange">
#  <barchart-field binding="true" class="quoteDown" name="percentChange" symbol="ATD.TO" type="percentChange" value="-0.35%">-0.35%<span class="sr-only">decrease</span></barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="openPrice" data-barchart-field-type="openPrice">
#  <barchart-field binding="true" name="openPrice" symbol="ATD.TO" type="price" value="72.71">72.71</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="highPrice" data-barchart-field-type="highPrice">
#  <barchart-field binding="true" name="highPrice" symbol="ATD.TO" type="price" value="73.20">73.20</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="lowPrice" data-barchart-field-type="lowPrice">
#  <barchart-field binding="true" name="lowPrice" symbol="ATD.TO" type="price" value="72.02">72.02</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="tradeTime" data-barchart-field-type="tradeTime">
#  <barchart-field binding="true" name="tradeTime" symbol="ATD.TO" type="time" value="06/06/25">06/06/25</barchart-field>
#  </td>
#  <td class="text-right hidden-print" data-barchart-field="quickLink" data-barchart-field-type="quickLink">
#  <barchart-quick-link quicklinks='{"links":{"1":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"},{"label":"Insiders","link":"{symbol}/insiders/"}],"2":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Related","link":"{symbol}/related/"},{"label":"Daily Price","link":"{symbol}/performance/"}],"5":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Research","link":"{symbol}/fundamentals/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"6":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"},{"label":"Insiders","link":"{symbol}/insiders/"}],"7":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"9":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Components","link":"{symbol}/components/"},{"label":"Daily Price","link":"{symbol}/performance/"}],"10":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"}],"11":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"15":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Research","link":"{symbol}/fundamentals/"},{"label":"Daily Prices","link":"{symbol}/performance/"}]},"tools":[{"label":"Add to Watchlist","attributeType":"barchart-watchlist"},{"label":"Add to Portfolio","attributeType":"barchart-portfolio"},{"label":"Create Alert","attributeType":"barchart-alert"}]}' quote='{"symbol":"ATD-T","symbolName":"Alimentation Couche-Tard Inc.","lastPrice":"72.14","priceChange":"-0.25","percentChange":"-0.35%","openPrice":"72.71","highPrice":"73.20","lowPrice":"72.02","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"ATD.TO","symbolName":"Alimentation Couche-Tard Inc.","lastPrice":72.14,"priceChange":-0.25,"percentChange":-0.0035,"openPrice":72.71,"highPrice":73.2,"lowPrice":72.02,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}' symbol="ATD-T" symboltype="6"><div class="quick-action-containers">
#  <!-- <span tabindex="0" role="button" class="quick-action glyphicon glyphicon-option-horizontal" data-toggle="popover" data-trigger="click"></span> -->
#  <span class="quick-action glyphicon glyphicon-option-horizontal"></span>
#  <!-- <a tabindex="0" role="button" class="quick-action glyphicon glyphicon-option-horizontal" data-toggle="popover" data-trigger="click"></a> -->
#  <div class="barchart-tool-link-container hidden">
#  <!-- <div class="barchart-point popover-content"> -->
#  <div class="barchart-point">
#  <div class="links-container">
#  <div class="action-titles action-titles-top">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Links
#                              </h5>
#  </div>
#  </div>
#  <div class="action-links">
#  <div class="link-holder row">
#  <div class="col-xs-6">
#  <a class="links" href="/investing/markets/stocks/ATD-T/">
#                                  Quote
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/full-chart/ATD-T/">
#                                  Chart
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ATD-T/profile/">
#                                  Profile
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ATD-T/statistics/">
#                                  Statistics
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ATD-T/financials/">
#                                  Earnings
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ATD-T/dividends/">
#                                  Dividends
#                                  </a>
#  </div><div class="col-xs-6">
#  <a class="links" href="/investing/markets/stocks/ATD-T/research/">
#                                  Research
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ATD-T/pressreleases/">
#                                  Press
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ATD-T/performance/">
#                                  Daily Prices
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/ATD-T/insiders/">
#                                  Insiders
#                                  </a>
#  </div>
#  </div>
#  </div>
#  <div class="action-titles action-titles-bottom hidden">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Links
#                              </h5>
#  </div>
#  </div>
#  </div>
#  <div class="links-container">
#  <div class="action-titles action-titles-top">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Tools
#                              </h5>
#  </div>
#  </div>
#  <div class="action-links">
#  <div class="link-holder">
#  <a class="tools bc-add-to-watchlist" is="barchart-watchlist" quote='{"symbol":"ATD-T","symbolName":"Alimentation Couche-Tard Inc.","lastPrice":"72.14","priceChange":"-0.25","percentChange":"-0.35%","openPrice":"72.71","highPrice":"73.20","lowPrice":"72.02","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"ATD.TO","symbolName":"Alimentation Couche-Tard Inc.","lastPrice":72.14,"priceChange":-0.25,"percentChange":-0.0035,"openPrice":72.71,"highPrice":73.2,"lowPrice":72.02,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Add to Watchlist
#                                  </a>
#  <a class="tools" is="barchart-portfolio" quote='{"symbol":"ATD-T","symbolName":"Alimentation Couche-Tard Inc.","lastPrice":"72.14","priceChange":"-0.25","percentChange":"-0.35%","openPrice":"72.71","highPrice":"73.20","lowPrice":"72.02","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"ATD.TO","symbolName":"Alimentation Couche-Tard Inc.","lastPrice":72.14,"priceChange":-0.25,"percentChange":-0.0035,"openPrice":72.71,"highPrice":73.2,"lowPrice":72.02,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Add to Portfolio
#                                  </a>
#  <a class="tools" is="barchart-alert" quote='{"symbol":"ATD-T","symbolName":"Alimentation Couche-Tard Inc.","lastPrice":"72.14","priceChange":"-0.25","percentChange":"-0.35%","openPrice":"72.71","highPrice":"73.20","lowPrice":"72.02","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"ATD.TO","symbolName":"Alimentation Couche-Tard Inc.","lastPrice":72.14,"priceChange":-0.25,"percentChange":-0.0035,"openPrice":72.71,"highPrice":73.2,"lowPrice":72.02,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Create Alert
#                                  </a>
#  </div>
#  </div>
#  <div class="action-titles action-titles-bottom hidden">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Tools
#                              </h5>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div></barchart-quick-link>
#  </td>
#  </tr>,
#  <tr data-barchart-symbol="BAM-T">
#  <td class="fix-col text-left" data-barchart-field="symbol" data-barchart-field-type="symbol">
#  <barchart-link-field raw-symbol="BAM.TO" symbol="BAM-T" symbolname="Brookfield Asset Management Ltd" type="6" value="BAM-T">
#  <a href="/investing/markets/stocks/BAM-T/">BAM-T</a>
#  </barchart-link-field>
#  </td>
#  <td class="text-left" data-barchart-field="symbolName" data-barchart-field-type="symbolName">
#  <barchart-field binding="true" name="symbolName" symbol="BAM.TO" type="string" value="Brookfield Asset Management Ltd">Brookfield Asset Management Ltd</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="lastPrice" data-barchart-field-type="lastPrice">
#  <barchart-field binding="true" name="lastPrice" symbol="BAM.TO" type="price" value="78.78">78.78</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="priceChange" data-barchart-field-type="priceChange">
#  <barchart-field binding="true" class="quoteUp" name="priceChange" symbol="BAM.TO" type="priceChange" value="+1.41">+1.41<span class="sr-only">increase</span></barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="percentChange" data-barchart-field-type="percentChange">
#  <barchart-field binding="true" class="quoteUp" name="percentChange" symbol="BAM.TO" type="percentChange" value="+1.82%">+1.82%<span class="sr-only">increase</span></barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="openPrice" data-barchart-field-type="openPrice">
#  <barchart-field binding="true" name="openPrice" symbol="BAM.TO" type="price" value="78.11">78.11</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="highPrice" data-barchart-field-type="highPrice">
#  <barchart-field binding="true" name="highPrice" symbol="BAM.TO" type="price" value="78.93">78.93</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="lowPrice" data-barchart-field-type="lowPrice">
#  <barchart-field binding="true" name="lowPrice" symbol="BAM.TO" type="price" value="78.04">78.04</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="tradeTime" data-barchart-field-type="tradeTime">
#  <barchart-field binding="true" name="tradeTime" symbol="BAM.TO" type="time" value="06/06/25">06/06/25</barchart-field>
#  </td>
#  <td class="text-right hidden-print" data-barchart-field="quickLink" data-barchart-field-type="quickLink">
# ...
#  <span class="quick-action glyphicon glyphicon-option-horizontal"></span>
#  <!-- <a tabindex="0" role="button" class="quick-action glyphicon glyphicon-option-horizontal" data-toggle="popover" data-trigger="click"></a> -->
#  <div class="barchart-tool-link-container hidden">
#  <!-- <div class="barchart-point popover-content"> -->
#  <div class="barchart-point">
#  <div class="links-container">
#  <div class="action-titles action-titles-top">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Links
#                              </h5>
#  </div>
#  </div>
#  <div class="action-links">
#  <div class="link-holder row">
#  <div class="col-xs-6">
#  <a class="links" href="/investing/markets/stocks/WPM-T/">
#                                  Quote
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/full-chart/WPM-T/">
#                                  Chart
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WPM-T/profile/">
#                                  Profile
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WPM-T/statistics/">
#                                  Statistics
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WPM-T/financials/">
#                                  Earnings
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WPM-T/dividends/">
#                                  Dividends
#                                  </a>
#  </div><div class="col-xs-6">
#  <a class="links" href="/investing/markets/stocks/WPM-T/research/">
#                                  Research
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WPM-T/pressreleases/">
#                                  Press
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WPM-T/performance/">
#                                  Daily Prices
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WPM-T/insiders/">
#                                  Insiders
#                                  </a>
#  </div>
#  </div>
#  </div>
#  <div class="action-titles action-titles-bottom hidden">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Links
#                              </h5>
#  </div>
#  </div>
#  </div>
#  <div class="links-container">
#  <div class="action-titles action-titles-top">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Tools
#                              </h5>
#  </div>
#  </div>
#  <div class="action-links">
#  <div class="link-holder">
#  <a class="tools bc-add-to-watchlist" is="barchart-watchlist" quote='{"symbol":"WPM-T","symbolName":"Wheaton Precious Metals Corp","lastPrice":"121.52","priceChange":"-3.69","percentChange":"-2.95%","openPrice":"125.44","highPrice":"125.59","lowPrice":"121.07","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"WPM.TO","symbolName":"Wheaton Precious Metals Corp","lastPrice":121.52,"priceChange":-3.69,"percentChange":-0.0295,"openPrice":125.44,"highPrice":125.59,"lowPrice":121.07,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Add to Watchlist
#                                  </a>
#  <a class="tools" is="barchart-portfolio" quote='{"symbol":"WPM-T","symbolName":"Wheaton Precious Metals Corp","lastPrice":"121.52","priceChange":"-3.69","percentChange":"-2.95%","openPrice":"125.44","highPrice":"125.59","lowPrice":"121.07","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"WPM.TO","symbolName":"Wheaton Precious Metals Corp","lastPrice":121.52,"priceChange":-3.69,"percentChange":-0.0295,"openPrice":125.44,"highPrice":125.59,"lowPrice":121.07,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Add to Portfolio
#                                  </a>
#  <a class="tools" is="barchart-alert" quote='{"symbol":"WPM-T","symbolName":"Wheaton Precious Metals Corp","lastPrice":"121.52","priceChange":"-3.69","percentChange":"-2.95%","openPrice":"125.44","highPrice":"125.59","lowPrice":"121.07","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"WPM.TO","symbolName":"Wheaton Precious Metals Corp","lastPrice":121.52,"priceChange":-3.69,"percentChange":-0.0295,"openPrice":125.44,"highPrice":125.59,"lowPrice":121.07,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Create Alert
#                                  </a>
#  </div>
#  </div>
#  <div class="action-titles action-titles-bottom hidden">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Tools
#                              </h5>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div></barchart-quick-link>
#  </td>
#  </tr>,
#  <tr data-barchart-symbol="WSP-T">
#  <td class="fix-col text-left" data-barchart-field="symbol" data-barchart-field-type="symbol">
#  <barchart-link-field raw-symbol="WSP.TO" symbol="WSP-T" symbolname="WSP Global Inc" type="6" value="WSP-T">
#  <a href="/investing/markets/stocks/WSP-T/">WSP-T</a>
#  </barchart-link-field>
#  </td>
#  <td class="text-left" data-barchart-field="symbolName" data-barchart-field-type="symbolName">
#  <barchart-field binding="true" name="symbolName" symbol="WSP.TO" type="string" value="WSP Global Inc">WSP Global Inc</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="lastPrice" data-barchart-field-type="lastPrice">
#  <barchart-field binding="true" name="lastPrice" symbol="WSP.TO" type="price" value="277.52">277.52</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="priceChange" data-barchart-field-type="priceChange">
#  <barchart-field binding="true" class="quoteUp" name="priceChange" symbol="WSP.TO" type="priceChange" value="+1.88">+1.88<span class="sr-only">increase</span></barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="percentChange" data-barchart-field-type="percentChange">
#  <barchart-field binding="true" class="quoteUp" name="percentChange" symbol="WSP.TO" type="percentChange" value="+0.68%">+0.68%<span class="sr-only">increase</span></barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="openPrice" data-barchart-field-type="openPrice">
#  <barchart-field binding="true" name="openPrice" symbol="WSP.TO" type="price" value="277.19">277.19</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="highPrice" data-barchart-field-type="highPrice">
#  <barchart-field binding="true" name="highPrice" symbol="WSP.TO" type="price" value="277.61">277.61</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="lowPrice" data-barchart-field-type="lowPrice">
#  <barchart-field binding="true" name="lowPrice" symbol="WSP.TO" type="price" value="275.63">275.63</barchart-field>
#  </td>
#  <td class="text-right" data-barchart-field="tradeTime" data-barchart-field-type="tradeTime">
#  <barchart-field binding="true" name="tradeTime" symbol="WSP.TO" type="time" value="06/06/25">06/06/25</barchart-field>
#  </td>
#  <td class="text-right hidden-print" data-barchart-field="quickLink" data-barchart-field-type="quickLink">
#  <barchart-quick-link quicklinks='{"links":{"1":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"},{"label":"Insiders","link":"{symbol}/insiders/"}],"2":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Related","link":"{symbol}/related/"},{"label":"Daily Price","link":"{symbol}/performance/"}],"5":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Research","link":"{symbol}/fundamentals/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"6":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"},{"label":"Insiders","link":"{symbol}/insiders/"}],"7":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Dividends","link":"{symbol}/dividends/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"9":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Components","link":"{symbol}/components/"},{"label":"Daily Price","link":"{symbol}/performance/"}],"10":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"}],"11":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Profile","link":"{symbol}/profile/"},{"label":"Statistics","link":"{symbol}/statistics/"},{"label":"Earnings","link":"{symbol}/financials/"},{"label":"Dividends","link":"{symbol}/dividends"},{"label":"Research","link":"{symbol}/research/"},{"label":"Press","link":"{symbol}/pressreleases/"},{"label":"Daily Prices","link":"{symbol}/performance/"}],"15":[{"label":"Quote","link":"{symbol}/"},{"label":"Chart","link":"full-chart/{symbol}/"},{"label":"Research","link":"{symbol}/fundamentals/"},{"label":"Daily Prices","link":"{symbol}/performance/"}]},"tools":[{"label":"Add to Watchlist","attributeType":"barchart-watchlist"},{"label":"Add to Portfolio","attributeType":"barchart-portfolio"},{"label":"Create Alert","attributeType":"barchart-alert"}]}' quote='{"symbol":"WSP-T","symbolName":"WSP Global Inc","lastPrice":"277.52","priceChange":"+1.88","percentChange":"+0.68%","openPrice":"277.19","highPrice":"277.61","lowPrice":"275.63","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"WSP.TO","symbolName":"WSP Global Inc","lastPrice":277.52,"priceChange":1.88,"percentChange":0.0068,"openPrice":277.19,"highPrice":277.61,"lowPrice":275.63,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}' symbol="WSP-T" symboltype="6"><div class="quick-action-containers">
#  <!-- <span tabindex="0" role="button" class="quick-action glyphicon glyphicon-option-horizontal" data-toggle="popover" data-trigger="click"></span> -->
#  <span class="quick-action glyphicon glyphicon-option-horizontal"></span>
#  <!-- <a tabindex="0" role="button" class="quick-action glyphicon glyphicon-option-horizontal" data-toggle="popover" data-trigger="click"></a> -->
#  <div class="barchart-tool-link-container hidden">
#  <!-- <div class="barchart-point popover-content"> -->
#  <div class="barchart-point">
#  <div class="links-container">
#  <div class="action-titles action-titles-top">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Links
#                              </h5>
#  </div>
#  </div>
#  <div class="action-links">
#  <div class="link-holder row">
#  <div class="col-xs-6">
#  <a class="links" href="/investing/markets/stocks/WSP-T/">
#                                  Quote
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/full-chart/WSP-T/">
#                                  Chart
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WSP-T/profile/">
#                                  Profile
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WSP-T/statistics/">
#                                  Statistics
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WSP-T/financials/">
#                                  Earnings
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WSP-T/dividends/">
#                                  Dividends
#                                  </a>
#  </div><div class="col-xs-6">
#  <a class="links" href="/investing/markets/stocks/WSP-T/research/">
#                                  Research
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WSP-T/pressreleases/">
#                                  Press
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WSP-T/performance/">
#                                  Daily Prices
#                                  </a>
#  <a class="links" href="/investing/markets/stocks/WSP-T/insiders/">
#                                  Insiders
#                                  </a>
#  </div>
#  </div>
#  </div>
#  <div class="action-titles action-titles-bottom hidden">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Links
#                              </h5>
#  </div>
#  </div>
#  </div>
#  <div class="links-container">
#  <div class="action-titles action-titles-top">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Tools
#                              </h5>
#  </div>
#  </div>
#  <div class="action-links">
#  <div class="link-holder">
#  <a class="tools bc-add-to-watchlist" is="barchart-watchlist" quote='{"symbol":"WSP-T","symbolName":"WSP Global Inc","lastPrice":"277.52","priceChange":"+1.88","percentChange":"+0.68%","openPrice":"277.19","highPrice":"277.61","lowPrice":"275.63","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"WSP.TO","symbolName":"WSP Global Inc","lastPrice":277.52,"priceChange":1.88,"percentChange":0.0068,"openPrice":277.19,"highPrice":277.61,"lowPrice":275.63,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Add to Watchlist
#                                  </a>
#  <a class="tools" is="barchart-portfolio" quote='{"symbol":"WSP-T","symbolName":"WSP Global Inc","lastPrice":"277.52","priceChange":"+1.88","percentChange":"+0.68%","openPrice":"277.19","highPrice":"277.61","lowPrice":"275.63","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"WSP.TO","symbolName":"WSP Global Inc","lastPrice":277.52,"priceChange":1.88,"percentChange":0.0068,"openPrice":277.19,"highPrice":277.61,"lowPrice":275.63,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Add to Portfolio
#                                  </a>
#  <a class="tools" is="barchart-alert" quote='{"symbol":"WSP-T","symbolName":"WSP Global Inc","lastPrice":"277.52","priceChange":"+1.88","percentChange":"+0.68%","openPrice":"277.19","highPrice":"277.61","lowPrice":"275.63","tradeTime":"06/06/25","symbolType":6,"exchange":"TSX","symbolCurrency":"CAD","raw":{"symbol":"WSP.TO","symbolName":"WSP Global Inc","lastPrice":277.52,"priceChange":1.88,"percentChange":0.0068,"openPrice":277.19,"highPrice":277.61,"lowPrice":275.63,"tradeTime":1749246180,"symbolType":6,"exchange":"TSX","symbolCurrency":"CAD"}}'>
#                                  Create Alert
#                                  </a>
#  </div>
#  </div>
#  <div class="action-titles action-titles-bottom hidden">
#  <div class="action-holder">
#  <h5 class="text-left">
#                                  Tools
#                              </h5>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div></barchart-quick-link>
#  </td>
#  </tr>]

# %%
symbols = [tr['data-barchart-symbol'] for tr in a]
symbols
# Out:
# ['ABX-T',
#  'AEM-T',
#  'AQN-T',
#  'ATD-T',
#  'BAM-T',
#  'BCE-T',
#  'BIP-UN-T',
#  'BMO-T',
#  'BN-T',
#  'BNS-T',
#  'CAE-T',
#  'CAR-UN-T',
#  'CCL-B-T',
#  'CCO-T',
#  'CM-T',
#  'CNQ-T',
#  'CNR-T',
#  'CP-T',
#  'CSU-T',
#  'CTC-A-T',
#  'CVE-T',
#  'DOL-T',
#  'EMA-T',
#  'ENB-T',
#  'FM-T',
#  'FNV-T',
#  'FSV-T',
#  'FTS-T',
#  'GIB-A-T',
#  'GIL-T',
#  'H-T',
#  'IFC-T',
#  'IMO-T',
#  'K-T',
#  'L-T',
#  'MFC-T',
#  'MG-T',
#  'MRU-T',
#  'NA-T',
#  'NTR-T',
#  'OTEX-T',
#  'POW-T',
#  'PPL-T',
#  'QSR-T',
#  'RCI-B-T',
#  'RY-T',
#  'SAP-T',
#  'SHOP-T',
#  'SLF-T',
#  'SU-T',
#  'T-T',
#  'TD-T',
#  'TECK-B-T',
#  'TOU-T',
#  'TRI-T',
#  'TRP-T',
#  'WCN-T',
#  'WN-T',
#  'WPM-T',
#  'WSP-T']

# %%
len(symbols)
# Out:
# 60

# %% [markdown]
# Now we get the tickers of 60 stocks on TSX 60
#
# But we need to convert these tickers to Bloomberg version of ticker name.

# %%
# remove the -T suffix from each element
clean_symbols = [s.replace('-T', '') for s in symbols]
clean_symbols
# Out:
# ['ABX',
#  'AEM',
#  'AQN',
#  'ATD',
#  'BAM',
#  'BCE',
#  'BIP-UN',
#  'BMO',
#  'BN',
#  'BNS',
#  'CAE',
#  'CAR-UN',
#  'CCL-B',
#  'CCO',
#  'CM',
#  'CNQ',
#  'CNR',
#  'CP',
#  'CSU',
#  'CTC-A',
#  'CVE',
#  'DOL',
#  'EMA',
#  'ENB',
#  'FM',
#  'FNV',
#  'FSV',
#  'FTS',
#  'GIB-A',
#  'GIL',
#  'H',
#  'IFC',
#  'IMO',
#  'K',
#  'L',
#  'MFC',
#  'MG',
#  'MRU',
#  'NA',
#  'NTR',
#  'OTEX',
#  'POW',
#  'PPL',
#  'QSR',
#  'RCI-B',
#  'RY',
#  'SAP',
#  'SHOP',
#  'SLF',
#  'SU',
#  'T',
#  'TD',
#  'TECK-B',
#  'TOU',
#  'TRI',
#  'TRP',
#  'WCN',
#  'WN',
#  'WPM',
#  'WSP']
